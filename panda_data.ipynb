# %%
! pip install scipy

# %%
# Databricks notebook source
# MAGIC %pip install ydata-profiling==4.0.0 --upgrade --force-reinstall scipy

# COMMAND ----------




# COMMAND ----------

from pyspark.sql import SparkSession

# Load data into DataFrame using SQL query
df = SparkSession.sql("SELECT * FROM edap_stg.plm_c_chem_react1")
df = SparkSession.table('edap_stg.plm_c_chem_react1').cache()
display(df)
# Write DataFrame to Delta table




# COMMAND ----------



# COMMAND ----------

df = SparkSession.table('edap_stg.plm_c_chem_react1').cache()
display(df)


# COMMAND ----------

import scipy
import scipy.stats
#now you can use
scipy.stats.poisson
#if you want it more accessible you could do what you did above
from scipy.stats import poisson
#then call poisson directly
poisson

# COMMAND ----------

from ydata_profiling import ProfileReport
report = ProfileReport(df,
                title='Triq',
                infer_dtypes=False,
                interactions=None,
                missing_diagrams=None,
                correlations={"auto": {"calculate": False},
                              "pearson": {"calculate": True},
                              "spearman": {"calculate": True}})

# COMMAND ----------

report

# COMMAND ----------

report.to_file('/dbfs/FileStore/plm_c_chem_react.json')


# COMMAND ----------

report.to_file('taxi_trip1.json')

# COMMAND ----------

import pandas as pd
import json

# COMMAND ----------

import os
print(os.getcwd())

# COMMAND ----------

import os
print(os.getcwd())

file_name = 'taxi_trip3.json'  # Replace 'example.txt' with your file name

# Construct the full file path
file_path = os.path.join(os.getcwd(), file_name)

# Open the file for reading
with open(file_path, 'r') as file:
    # Read the contents of the file
    contents = file.read()
    # Print the contents

# COMMAND ----------

import os

file_name = 'plm_c_chem_react.json'  # Replace 'example.txt' with your file name

# Construct the full file path
file_path = os.path.join('/dbfs/FileStore/', file_name)

# Open the file for reading
with open(file_path, 'r') as file:
    # Read the contents of the file
    contents = file.read()

    # Print the contents
    print(contents)

# COMMAND ----------



# COMMAND ----------

report_html = report.to_html()
displayHTML(report_html)

# COMMAND ----------

# MAGIC %sql
# MAGIC select * from edap_stg.plm_c_chem_react1

# COMMAND ----------
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 14
#      11 from pyspark.sql import SparkSession
#      13 # Load data into DataFrame using SQL query
# ---> 14 df = SparkSession.sql("SELECT * FROM edap_stg.plm_c_chem_react1")
#      15 df = SparkSession.table('edap_stg.plm_c_chem_react1').cache()
#      16 display(df)
#
# TypeError: SparkSession.sql() missing 1 required positional argument: 'sqlQuery'

# %%
import pandas as pd
# from scipy.stats import poisson
from pandas_profiling import ProfileReport


df = pd.read_csv('gx_new .csv')


print(df)

# Calculate Poisson distribution
# poisson_dist = poisson(df)

# Generate profiling report
report = ProfileReport(df, title='Your Data Profiling Report', explorative=True)

# Save report to HTML file
report.to_file('your_data_profile.html')

report_html = report.to_html()
print(report_html)
# Out:
#       Name  Age  Salary   ID
# 0   booker   23   55000  212
# 1     grey   56   29000  218
# 2  johnson   43   45400  658
# 3  jenkins   23   32400  233
# 4    smith   32   30000  667
# 5   Rachel   45   49000  235
# 6    Laura   54   60330  898
# 7    Craig   29   54346  213
# 8     Mary   38   45346  678
# 9    Jamie   25   45460  123
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# <!doctype html><html lang=en><head><meta charset=utf-8><meta name=viewport content="width=device-width, initial-scale=1, shrink-to-fit=no"><meta name=description content="Profile report generated by YData! Visit us at https://ydata.ai"><meta name=author content="YData and the open source community."><meta name=generator content="Pandas Profiling vv4.6.4"><meta name=url content=https://github.com/ydataai/ydata-profiling><meta name=date content="2024-02-20 12:53:03.817560"><title>Your Data Profiling Report</title><style>
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport


df = pd.read_csv('gx_new .csv')

report = ProfileReport(df, title='Your Data Profiling Report', explorative=True)

# Convert the report to JSON format
report_json = report.to_json()

# Save the JSON report to a file
with open('your_data_profile.json', 'w') as json_file:
    json_file.write(report_json)

# Display HTML report
report_html = report.to_html()
print(report_html)
# Out:
# /tmp/ipykernel_649789/3871634288.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /tmp/ipykernel_649789/3871634288.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
import json

with open('your_data_profile.json', 'r') as json_file:
    report_json = json.load(json_file)


print(report_json.keys())

# Extract specific sections or information from the report JSON
variables = report_json['variables']


custom_section = {
    "name": "Custom Section",
    "content": "This is a custom section added programmatically."
}
report_json['custom_section'] = custom_section

# Save the modified report JSON to a new file
with open('modified_report.json', 'w') as json_file:
    json.dump(report_json, json_file, indent=4)
# Out:
# dict_keys(['analysis', 'time_index_analysis', 'table', 'variables', 'scatter', 'correlations', 'missing', 'alerts', 'package', 'sample', 'duplicates'])

# %%
! pip install json2html
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: json2html is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for json2html ... done
# ...

# %%
from json2html import json2html
with open('modified_report.json', 'r') as json_file:
    modified_report_json = json.load(json_file)

# Convert the modified report JSON to HTML format
html_report = json2html.convert(json=modified_report_json)

# Save the HTML report to a file
with open('modified_report.html', 'w') as html_file:
    html_file.write(html_report)
